# %%
from IPython.display import clear_output
import time

# %%
# Определим гиперпараметры
delta, h = 1, 100

# lags = [5, 10, 20, 50, 100, 200]

# %store delta
# %store h
# Out:
# Stored 'delta' (int)
# Stored 'h' (int)

# %%
# %run data_processing.ipynb
clear_output()

# %%
# Определим гиперпараметры
sigmas = [0, 0.001, 0.01, 0.03, 0.05]
batch_sizes = [16, 32, 64, 128, 256]

batch_size = 128
# %store batch_size
# Out:
# Stored 'batch_size' (int)

# %%
try:
    for sigma in sigmas:
        # %store sigma
        # %run evaluation.ipynb
except KeyboardInterrupt as e:
    clear_output()
    print("hehe")
